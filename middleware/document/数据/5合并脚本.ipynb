# %%
from openpyxl import load_workbook
from html.parser import HTMLParser
import requests,base64,os
from xml.etree import ElementTree  as ET
# 运行之前记得关闭DevSidecar或者别的代理工具


# 从1、GetLisRequest 接口（获取标本信息）
def get_patient_info(hospSampleID):
    data = f'''<?xml version="1.0" encoding="utf-8"?>
            <soap12:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:soap12="http://www.w3.org/2003/05/soap-envelope">
            <soap12:Body><GetLisRequest xmlns="http://tempuri.org/"><hospSampleID>{hospSampleID}</hospSampleID>
            </GetLisRequest></soap12:Body></soap12:Envelope>'''
    encode_data = data.encode('utf-8')
    # print(data)
    headers = {"Host": "10.10.11.196",
            "Content-Type": "application/soap+xml; charset=UTF-8",
            "Content-Length": str(len(encode_data)),
            "SOAPAction": "http://tempuri.org/GetLisRequest"}
    patient_info = requests.post('http://58.62.17.237:4431/ExtReportService', data=encode_data ,headers=headers)

    # print('patient_info.header----')
    # print(patient_info.headers)
    # print('patient_info.text----') 
    # print(patient_info.text)

    return patient_info.text


class Parse(HTMLParser):
    def __init__(self):
    #Since Python 3, we need to call the __init__() function 
    #of the parent class
        super().__init__()
        self.reset()
        self.data = None
 
    def handle_data(self, data):
        # print("Here's the data: ", data)
        print('HTMLParser parsering data ')
        self.data = data

 
 # 解析1GetLisRequest返回的xml信息：
def get_LisRequest_data(patient_info):
    def get_tag_raw(tag_name):
        return root[0].find(tag_name).text    
    dct = {}
    parser = Parse()
    parser.feed(patient_info)
    data = parser.data
    root = ET.fromstring(data)
    
    dct['lis_Barcode'] = get_tag_raw('lis_Barcode')
    dct['blood_time'] = get_tag_raw('blood_time') 
    dct['lis_combine_code'] = root[0].find('LisItems').find('lis_item_code').text
        
    all_sub_items = root[0].find('LisItems').findall('SubItems') 
    dct['all_lis_item_code'] =  [item.find('lis_subitem_code').text for item in all_sub_items]
    dct['all_lis_item_name'] =  [item.find('lis_subitem_name').text for item in all_sub_items]    
       
    # print('----patient_info-all_lis_item_name dct -----') 
    # print(dct)
    # print(all_lis_item_name)
    # with open('xmlfile/'+dct['lis_Barcode'] +'.xml','w',encoding='utf-8') as fh:
    #     fh.write(data)
    # return lis_Barcode,blood_time,lis_combine_code,all_lis_item_code
    return dct
   

# 解析Excel报告的信息,这里的flag有两个，分别是5和17，
# 如果是5，那就是 “雄激素5项(爱湾)”，如果是17，那就代表“17α-羟孕酮”
# def get_excel_info(infile,hospSampleID,flag = '5'):
def get_excel_info(infile,flag = '5'):
    # all_lis_item_code =  ['32378', '32379', '32380', '32381', '32383']
    # patient_info = get_patient_info(hospSampleID)
    # dct = get_LisRequest_data(patient_info)
    dct = {}
    ex  = load_workbook(infile)
    tb = ex['报告']
    lis_Barcode= tb.cell(row=4,column=3).value
    if flag == '5':
        dct['lis_Barcode']   = str(lis_Barcode).split('+')[0]        
    if flag == '17':
        try:
            dct['lis_Barcode']   = str(lis_Barcode).split('+')[-1]
        except Exception as e:
            print('lenth of lis_Barcode is less than 2 ')
            print(lis_Barcode)
            print(e)
            
    # 采样日期：	
    dct['blood_time'] = tb.cell(row=6,column=3).value
    dct['ext_receive_time'],dct['ext_check_time'],dct['ext_report_time'] =  tb.cell(row=7,column=3).value, \
                                                                            tb.cell(row=7,column=7).value, \
                                                                            tb.cell(row=7,column=10).value
   # sheet里面从B10到H16,即检测结果的内容：
    result_info = ''
    result_dct = {}
    i  = 0
    all_lis_item_code =  ['32378', '32379', '32380', '32383', '32381','32382']
    all_lis_item_name =  ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '双氢睾酮', '脱氢表雄酮','17α-羟孕酮']
    all_lis_combine_code = ['32025']*5 + ['32024']
    all_ref = [
        "0.02-0.45",
        ' 0.30-2.35',
        '280-3900',
        '＜0.30',
        '19-30岁<13\n31-40岁<10\n41-50岁<8',
        '卵泡期0.09-2.00;黄体期0.3-2.34'
    ]
    result_unit = 'ng/mL'
    for row in range(10,16):
        i += 1
        if flag == '5' and i ==6:
            continue 
        if flag == '17' and i  in (1,2,3,4,5):
            continue 
#         result_dct['ext_item_code'] = all_lis_item_code
        result_dct['ext_item_code'] = all_lis_item_code[i-1]
        result_dct['lis_item_name'] = all_lis_item_name[i-1]
        # ext_item_name = tb.cell(row=row,column=2).value
        result_dct['lis_item_code'] = all_lis_item_code[i-1] 
        result_dct['result_reference'] = all_ref[i-1] 
        result_dct['result_unit'] = result_unit 
        result_dct['lis_combine_code'] = all_lis_combine_code[i-1]  

        result_dct['result'] = tb.cell(row=row,column=7).value   
        # print('lis_item_nam--------')
        # print(all_lis_item_name[i-1],all_lis_item_code[i-1] ,result_dct['result'] )
        # lis_item_name =  tb.cell(row=row,column=2).value
        result_dct['ext_combine_code'] = result_dct['lis_combine_code']
        
        result_info += set_result_info(result_dct)
    result_info = result_info + '<report_pic><pic_content>'  

    return result_info ,  dct



# 对每个检测项目的xml的result_info设置值
# 对每个检测项目的xml的result_info设置值
def set_result_info(dct):
    # print('*'*20)
    # print(dct)
    result_info = f'''    
    <result_info>
        <result_seq/>
        <ext_combine_code>{dct.get('ext_combine_code')}</ext_combine_code>
        <ext_combine_name>{dct.get('ext_combine_name')}</ext_combine_name>
        <ext_item_code>{dct.get('ext_item_code')}</ext_item_code>
        <ext_item_name>{dct.get('ext_item_name')}</ext_item_name>
        <result>        <![CDATA[{dct.get('result')}]]]]>>        <![CDATA[</result>
        <result_unit>        <![CDATA[{dct.get('result_unit')}]]]]>>   <![CDATA[</result_unit>
        <result_flag/>
        <result_reference>    <![CDATA[{dct.get('result_reference')}]]]]>>       <![CDATA[</result_reference>
        <result_date/>
        <result_intstrmt_name/>
        <result_test_method/>
        <result_suggestion/>
        <result_remark/>
        <lis_combine_code>{dct.get('lis_combine_code')}</lis_combine_code>
        <lis_combine_name>{dct.get('lis_combine_name')}</lis_combine_name>
        <lis_item_code>{dct.get('lis_item_code')}</lis_item_code>
        <lis_item_name>{dct.get('lis_item_name')}</lis_item_name>    
    </result_info>
   '''
    return result_info

# 要发送的xml的第一部分信息：
# import string 
def set_data1(dct):
    data1 = f'''
    <soap:Envelope
        xmlns:soap="http://www.w3.org/2003/05/soap-envelope"
        xmlns:tem="http://tempuri.org/">
        <soap:Header/>
        <soap:Body>
            <tem:UploadLisRepData>
                <!--Optional:-->
                <tem:reportResult>
                    <![CDATA[<Report_Result><Report_Info>
                    <ext_lab_code></ext_lab_code>
                    <lis_Barcode>{dct.get('lis_Barcode')}</lis_Barcode>
                    <ext_Barcode>{dct.get('ext_Barcode')}</ext_Barcode>
                    <ext_checkItem/>
                    <pat_name/>
                    <pat_age></pat_age>
                    <pat_height/>
                    <pat_wight/>
                    <pat_pre_week/>
                    <pat_id/>
                    <pat_bedNo/>
                    <pat_tel/>
                    <pat_sex/>
                    <pat_birthday/>
                    <pat_ori_name/>
                    <sam_name/>
                    <sam_state/>
                    <doctor_name/>
                    <dept_name/>
                    <clinical_diag/>
                    <SampleNumber/>
                    <blood_time>{dct.get('blood_time')}</blood_time>
                    <ext_check_ID/>
                    <ext_receive_time>{dct.get('ext_receive_time')}</ext_receive_time>
                    <ext_upload_time/>
                    <ext_report_suggestion/>
                    <ext_report_remark/>
                    <ext_intstrmt_name/>
                    <ext_lab_name/>
                    <ext_report_type/>
                    <ext_check_time/>
                    <ext_first_audit_time/>
                    <ext_first_audit_time/>
                    <ext_second_audit_time/>
                    <ext_checker/>
                    <ext_first_audit/>
                    <ext_second_audit/>
                    <ext_report_code>{dct.get('lis_Barcode')}</ext_report_code>
    '''
    return data1 


# pdf部分
def get_pdf(inpdf):
    data2 = ''
    with open(inpdf,'rb') as fh:
            data2 = base64.b64encode(fh.read())
    return data2

# 最后是将xml和pdf的信息发送到妇幼
def send_data(dct,data1,result_info,data2):
    # xml的结尾部分
    data3 = '''</pic_content><pic_name>{dct.get('lis_Barcode')}_report_base64.pdf</pic_name><pic_seq></pic_seq></report_pic></Report_Info></Report_Result>]]>
            </tem:reportResult>
        </tem:UploadLisRepData>
    </soap:Body>
</soap:Envelope>
    '''
    encode_data = data1.encode('utf-8') +result_info.encode('utf-8') + data2 +  data3.encode('utf-8')
    
    headers = {"Host": "10.10.11.196",
            "Content-Type": "text/xml; charset=utf-8",
            "Content-Length": str(len(encode_data)) ,#}
            "SOAPAction": "http://tempuri.org/UploadLisRepData"}
    print('********'*10)
    print('sending  lis_Barcode : ', dct.get('lis_Barcode') )

    if not os.path.exists('workdir'):
        os.mkdir('workdir')
    with open('./workdir/'+ dct.get('lis_Barcode') + '.xml','wb') as fh:
        fh.write(encode_data)
        
    patient_info = requests.post(f'http://58.62.17.237:4431/ExtReportService', data=encode_data ,headers=headers)
    # print('senting result ----')    
    # print(patient_info.text)
    if not os.path.exists('./result'):
        os.makedirs('./result')
    with open('./result/'+ dct.get('lis_Barcode') + '.txt','w') as out:
        out.write(patient_info.text)
    return patient_info.text
    

        
 #解压一个zip的文件到out_dir目录，在out_dir内自动新建以日期为名的目录。：       
def unzip_file(in_zipfile,out_dir):
    import datetime
    date_file = datetime.datetime.now().strftime("%Y_%m_%d") 
    out_dir = os.path.join(out_dir,date_file)
    f = zipfile.ZipFile(in_zipfile)
    for file_one in f.filelist:
        # f.extract(file,out_dir)
        file_one.filename = decode_filename(file_one.filename)
        f.extract(file_one,out_dir)
        
# 获取某个目录下面所有的xlsx文件：
def list_all_files(rootdir):
    import os
    _files = []
	# 列出文件夹下所有的目录与文件
    list = os.listdir(rootdir)
    for i in range(0, len(list)):
		# 构造路径
        path = os.path.join(rootdir, list[i])
		# 判断路径是否为文件目录或者文件
		# 如果是目录则继续递归
        if os.path.isdir(path):
            _files.extend(list_all_files(path))
        if os.path.isfile(path):
            if path.endswith('.xlsx'):
                _files.append(path)
    return _files

# 发送xml的主脚本
def main_send_2type(excel_file_path):
    file_path , excel_file_name = os.path.split(os.path.abspath(excel_file_path))
    def send_1type(flag):        
        result_info , dct = get_excel_info(excel_file_path,flag=flag)
        data1 = set_data1(dct)
        inpdf = excel_file_path.rstrip('xlsx') + 'pdf'
        data2 = get_pdf(inpdf)
        xml = send_data(dct,data1,result_info,data2)
        # parser = Parse()
        # parser.feed(patient_info)
        # data = parser.data
        tree = ET.fromstring(xml)
        result = tree[0][0][0].text
        print('-------发送结果：---------')
        print(result)
        print('-------发送的pdf：---------')
        print(inpdf)
        
    send_1type('5')
    send_1type('17')

# %%
def main():
    # hospSampleID = '100311224212'
    hospSampleID = '3243146536'

    # 1 读取：从1、GetLisRequest接口（获取标本信息）
    patient_info = get_patient_info(hospSampleID)
    lis_Barcode,blood_time,lis_combine_code,all_lis_item_code = get_LisRequest_data(patient_info)
    # 2 读取Excel：
    word_infile = 'E:/project/common/2022/05/5.26/省妇幼pcos报告-2022-05-25/省妇幼pcos报告-2022-05-25/何丽敏-激素检测报告-2022-05-25.xlsx'
    # get_excel_info(word_infile,hospSampleID)

# main()

# %%
# hospSampleID = '100311224212'

# 1 读取：从1、GetLisRequest接口（获取标本信息）
# patient_info = get_patient_info(hospSampleID)
# dct = get_LisRequest_data(patient_info)
# 2 读取Excel：
# word_infile = 'E:/project/common/2022/05/5.26/省妇幼pcos报告-2022-05-25/省妇幼pcos报告-2022-05-25/何丽敏-激素检测报告-2022-05-25.xlsx'

# %%
# print(result_info)

# %%
hospSampleID = '3243146536'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈嘉绮-激素检测报告-2022-05-25.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈嘉绮-激素检测报告-2022-05-25.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:29:44 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2300', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3243146536&lt;/lis_Barcode&gt;&lt;sample_no&gt;9&lt;/sample_no&gt;&lt;pat_no&gt;2001916719&lt;/pat_no&gt;&lt;pat_id&gt;2001916719&lt;/pat_id&gt;&lt;pat_name&gt;陈嘉绮&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:32:40&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1999-10-28 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;22&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;15007532931&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205269&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3243146536', 'blood_time': '2022-05-20 08:32:40', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.456
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.456, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 2.826
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 2.826, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1596.602
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1596.602, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.101
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.101, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 6.255
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 6.255, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈嘉绮-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '3343146537'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈嘉绮-激素检测报告-2022-05-25.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈嘉绮-激素检测报告-2022-05-25.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:29:56 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1706', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3343146537&lt;/lis_Barcode&gt;&lt;sample_no&gt;10&lt;/sample_no&gt;&lt;pat_no&gt;2001916719&lt;/pat_no&gt;&lt;pat_id&gt;2001916719&lt;/pat_id&gt;&lt;pat_name&gt;陈嘉绮&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:32:59&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1999-10-28 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;22&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;15007532931&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052610&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3343146537', 'blood_time': '2022-05-20 08:32:59', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 1.049
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 1.049, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>

# %%
hospSampleID = '2643164512'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:30:21 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2302', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2643164512&lt;/lis_Barcode&gt;&lt;sample_no&gt;19&lt;/sample_no&gt;&lt;pat_no&gt;2001915824&lt;/pat_no&gt;&lt;pat_id&gt;2001915824&lt;/pat_id&gt;&lt;pat_name&gt;陈钰莹&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-22 08:07:35&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;2004-01-29 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;18&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18718911827&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052619&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2643164512', 'blood_time': '2022-05-22 08:07:35', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.365
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.365, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.692
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 1.692, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1850.593
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1850.593, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.144
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.144, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.001
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.001, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2743164513'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:30:34 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1706', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2743164513&lt;/lis_Barcode&gt;&lt;sample_no&gt;20&lt;/sample_no&gt;&lt;pat_no&gt;2001915824&lt;/pat_no&gt;&lt;pat_id&gt;2001915824&lt;/pat_id&gt;&lt;pat_name&gt;陈钰莹&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-22 08:07:19&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;2004-01-29 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;18&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18718911827&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052620&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2743164513', 'blood_time': '2022-05-22 08:07:19', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.468
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.468, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/陈钰莹-激素检测报告-2022-05-25.pdf

# %%
# print(result_info ,lis_Barcode, blood_time, ext_receive_time, ext_check_time, ext_report_time)

# %% [markdown]
# lst_code = ["2343127051","4043146697","3143146922","2843125193","3243146536","2743136442","2243137022","2943156181","3243177523","2643164512","3343165806","2843173172"]
# # lst_code = ["2343127051"]
#
# def get_xml(lst_code):
#     for hospSampleID in lst_code:
#         patient_info = get_patient_info(hospSampleID)
#         get_LisRequest_data(patient_info)
#
# # get_xml(lst_code)

# %%
print('2')
# Out:
# 2

# %%
hospSampleID = '2343127051'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:31:02 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2342', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2343127051&lt;/lis_Barcode&gt;&lt;sample_no&gt;1&lt;/sample_no&gt;&lt;pat_no&gt;2001909006&lt;/pat_no&gt;&lt;pat_id&gt;2001909006&lt;/pat_id&gt;&lt;pat_name&gt;郝海萍&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-18 08:45:38&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1999-07-05 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;22&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13635831019&lt;/pat_tel&gt;&lt;dept_name&gt;生殖健康与不孕症科门诊(天河)&lt;/dept_name&gt;&lt;doctor_name&gt;王芳&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]不良孕产个人史;[西]月经不规则&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205251&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2343127051', 'blood_time': '2022-05-18 08:45:38', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.478
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.478, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 2.958
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 2.958, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2776.39
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 2776.39, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.098
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.098, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.752
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.752, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.pdf

# %%
hospSampleID = '2443127052'
infile = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')

data1 = set_data1(dct)
inpdf =  'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:31:10 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2322', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2443127052&lt;/lis_Barcode&gt;&lt;sample_no&gt;2443127052&lt;/sample_no&gt;&lt;pat_no&gt;2001909006&lt;/pat_no&gt;&lt;pat_id&gt;2001909006&lt;/pat_id&gt;&lt;pat_name&gt;郝海萍&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-18 08:45:41&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1999-07-05 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;22&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13635831019&lt;/pat_tel&gt;&lt;dept_name&gt;生殖健康与不孕症科门诊(天河)&lt;/dept_name&gt;&lt;doctor_name&gt;王芳&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]不良孕产个人史;[西]月经不规则&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10476202205182443127052&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;31868&lt;/lis_item_code&gt;&lt;lis_item_name&gt;睾酮&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;31157&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;31898&lt;/lis_item_code&gt;&lt;lis_item_name&gt;CA125&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;20113&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;糖类抗原CA125&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;31900&lt;/lis_item_code&gt;&lt;lis_item_name&gt;25-羟基维生素D&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;31571&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;25-羟基维生素D.&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2443127052', 'blood_time': '2022-05-18 08:45:41', 'lis_combine_code': '31868', 'all_lis_item_code': ['31157'], 'all_lis_item_name': ['睾酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 1.528
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 1.528, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郝海萍-激素检测报告-2022-05-20.pdf

# %%
hospSampleID = '4043146697'
file_name = '何丽敏-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 02:05:35 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2300', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;4043146697&lt;/lis_Barcode&gt;&lt;sample_no&gt;3&lt;/sample_no&gt;&lt;pat_no&gt;2001155124&lt;/pat_no&gt;&lt;pat_id&gt;2001155124&lt;/pat_id&gt;&lt;pat_name&gt;何丽敏&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:45:47&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1998-03-14 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;24&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13750079374&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205263&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '4043146697', 'blood_time': '2022-05-20 08:45:47', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.522
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.522, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 2.325
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 2.325, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1425.742
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1425.742, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.202
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.202, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.386
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 3.386, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何丽敏-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '4143146698'
file_name = '何丽敏-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:38:05 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1704', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;4143146698&lt;/lis_Barcode&gt;&lt;sample_no&gt;4&lt;/sample_no&gt;&lt;pat_no&gt;2001155124&lt;/pat_no&gt;&lt;pat_id&gt;2001155124&lt;/pat_id&gt;&lt;pat_name&gt;何丽敏&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:47:23&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1998-03-14 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;24&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13750079374&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205264&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '4143146698', 'blood_time': '2022-05-20 08:47:23', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 1.973
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 1.973, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何丽敏-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2743136442'
file_name = '何佩怡-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:43:00 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2341', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2743136442&lt;/lis_Barcode&gt;&lt;sample_no&gt;11&lt;/sample_no&gt;&lt;pat_no&gt;2001904103&lt;/pat_no&gt;&lt;pat_id&gt;2001904103&lt;/pat_id&gt;&lt;pat_name&gt;何佩怡&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 08:24:11&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1994-12-08 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;27&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;15603003986&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征;[西]血脂异常;[西]高尿酸血症&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052611&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2743136442', 'blood_time': '2022-05-19 08:24:11', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.316
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.316, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.591
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 1.591, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1528.774
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1528.774, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.052
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.052, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.369
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.369, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何佩怡-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2843136443'
file_name = '何佩怡-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 03:06:02 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1745', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2843136443&lt;/lis_Barcode&gt;&lt;sample_no&gt;12&lt;/sample_no&gt;&lt;pat_no&gt;2001904103&lt;/pat_no&gt;&lt;pat_id&gt;2001904103&lt;/pat_id&gt;&lt;pat_name&gt;何佩怡&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 08:24:27&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1994-12-08 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;27&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;15603003986&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征;[西]血脂异常;[西]高尿酸血症&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052612&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2843136443', 'blood_time': '2022-05-19 08:24:27', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.391
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.391, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何佩怡-激素检测报告-2022-05-25.pdf

# %%
file_name
# Out:
# '何佩怡-激素检测报告-2022-05-25'

# %%
file_path
# Out:
# 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何佩怡-激素检测报告-2022-05-25'

# %%
infile
# Out:
# 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/何佩怡-激素检测报告-2022-05-25.pdf'

# %%
hospSampleID = '3343165806'
file_name = '黄灵怡-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:44:00 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2338', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3343165806&lt;/lis_Barcode&gt;&lt;sample_no&gt;21&lt;/sample_no&gt;&lt;pat_no&gt;2000328597&lt;/pat_no&gt;&lt;pat_id&gt;2000328597&lt;/pat_id&gt;&lt;pat_name&gt;黄灵怡&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-22 09:23:36&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;2000-12-21 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;21&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13611480274&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]异常子宫出血;[西]多囊卵巢综合征;[西]痛经&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052621&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3343165806', 'blood_time': '2022-05-22 09:23:36', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.219
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.219, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.883
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 0.883, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1038.312
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1038.312, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.169
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.169, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.645
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.645, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>

# %%
hospSampleID = '3443165807'
file_name = '黄灵怡-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:44:08 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1742', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3443165807&lt;/lis_Barcode&gt;&lt;sample_no&gt;22&lt;/sample_no&gt;&lt;pat_no&gt;2000328597&lt;/pat_no&gt;&lt;pat_id&gt;2000328597&lt;/pat_id&gt;&lt;pat_name&gt;黄灵怡&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-22 09:23:42&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;2000-12-21 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;21&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13611480274&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]异常子宫出血;[西]多囊卵巢综合征;[西]痛经&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052622&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3443165807', 'blood_time': '2022-05-22 09:23:42', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 1.312
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 1.312, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>

# %%
hospSampleID = '3143146922'
file_name = '李捷-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:44:22 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2297', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3143146922&lt;/lis_Barcode&gt;&lt;sample_no&gt;5&lt;/sample_no&gt;&lt;pat_no&gt;2001913978&lt;/pat_no&gt;&lt;pat_id&gt;2001913978&lt;/pat_id&gt;&lt;pat_name&gt;李捷&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:46:30&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1997-02-17 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;25&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13600464776&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205265&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3143146922', 'blood_time': '2022-05-20 08:46:30', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.384
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.384, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.956
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 1.956, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 4097.152
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 4097.152, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.035
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.035, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.579
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 3.579, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>

# %%
hospSampleID = '3243146923'
file_name = '李捷-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:44:34 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1701', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3243146923&lt;/lis_Barcode&gt;&lt;sample_no&gt;6&lt;/sample_no&gt;&lt;pat_no&gt;2001913978&lt;/pat_no&gt;&lt;pat_id&gt;2001913978&lt;/pat_id&gt;&lt;pat_name&gt;李捷&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-20 08:47:03&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1997-02-17 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;25&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;13600464776&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205266&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3243146923', 'blood_time': '2022-05-20 08:47:03', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.591
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.591, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>

# %%
-----------------------

# %%
hospSampleID = '2243137022'
file_name = '刘晓翠-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf' 
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:48:39 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2341', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2243137022&lt;/lis_Barcode&gt;&lt;sample_no&gt;13&lt;/sample_no&gt;&lt;pat_no&gt;2001891777&lt;/pat_no&gt;&lt;pat_id&gt;2001891777&lt;/pat_id&gt;&lt;pat_name&gt;刘晓翠&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 08:57:47&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1991-10-22 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;30&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;17717371022&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征;[西]异常子宫出血;[西]脂肪肝&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052613&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2243137022', 'blood_time': '2022-05-19 08:57:47', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.192
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.192, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.851
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 0.851, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2229.482
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 2229.482, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.049
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.049, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.787
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 3.787, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/刘晓翠-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2343137023'
file_name = '刘晓翠-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:48:34 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1745', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2343137023&lt;/lis_Barcode&gt;&lt;sample_no&gt;14&lt;/sample_no&gt;&lt;pat_no&gt;2001891777&lt;/pat_no&gt;&lt;pat_id&gt;2001891777&lt;/pat_id&gt;&lt;pat_name&gt;刘晓翠&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 08:58:37&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1991-10-22 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;30&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;17717371022&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征;[西]异常子宫出血;[西]脂肪肝&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052614&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2343137023', 'blood_time': '2022-05-19 08:58:37', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.215
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.215, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/刘晓翠-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2943156181'
file_name = '罗冬红-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:48:10 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2296', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2943156181&lt;/lis_Barcode&gt;&lt;sample_no&gt;15&lt;/sample_no&gt;&lt;pat_no&gt;2001916669&lt;/pat_no&gt;&lt;pat_id&gt;2001916669&lt;/pat_id&gt;&lt;pat_name&gt;罗冬红&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-21 09:01:03&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1994-11-12 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;27&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18318011671&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(番禺)&lt;/dept_name&gt;&lt;doctor_name&gt;黄玲&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052615&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2943156181', 'blood_time': '2022-05-21 09:01:03', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.258
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.258, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.932
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 0.932, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1644.612
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1644.612, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.031
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.031, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.661
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.661, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/罗冬红-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '3043156182'
file_name = '罗冬红-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:48:26 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1700', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3043156182&lt;/lis_Barcode&gt;&lt;sample_no&gt;16&lt;/sample_no&gt;&lt;pat_no&gt;2001916669&lt;/pat_no&gt;&lt;pat_id&gt;2001916669&lt;/pat_id&gt;&lt;pat_name&gt;罗冬红&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-22 15:57:45&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1994-11-12 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;27&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18318011671&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(番禺)&lt;/dept_name&gt;&lt;doctor_name&gt;黄玲&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052616&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3043156182', 'blood_time': '2022-05-22 15:57:45', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.254
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.254, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/罗冬红-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '3243177523'
file_name = '潘琦-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:47:59 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2302', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3243177523&lt;/lis_Barcode&gt;&lt;sample_no&gt;17&lt;/sample_no&gt;&lt;pat_no&gt;2001921127&lt;/pat_no&gt;&lt;pat_id&gt;2001921127&lt;/pat_id&gt;&lt;pat_name&gt;潘琦&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-23 10:56:18&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1996-09-03 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;25&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18218192683&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(番禺)&lt;/dept_name&gt;&lt;doctor_name&gt;禤坚艳&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052617&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3243177523', 'blood_time': '2022-05-23 10:56:18', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.492
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.492, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.601
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 1.601, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2064.117
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 2064.117, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.141
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.141, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.172
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 3.172, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/潘琦-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '3343177524'
file_name = '潘琦-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:47:46 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1706', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;3343177524&lt;/lis_Barcode&gt;&lt;sample_no&gt;18&lt;/sample_no&gt;&lt;pat_no&gt;2001921127&lt;/pat_no&gt;&lt;pat_id&gt;2001921127&lt;/pat_id&gt;&lt;pat_name&gt;潘琦&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-23 10:56:24&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1996-09-03 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;25&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18218192683&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(番禺)&lt;/dept_name&gt;&lt;doctor_name&gt;禤坚艳&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]多囊卵巢综合征&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;104942022052618&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '3343177524', 'blood_time': '2022-05-23 10:56:24', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.641
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.641, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/潘琦-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2843125193'
file_name = '郑佳娜-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:47:38 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2352', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2843125193&lt;/lis_Barcode&gt;&lt;sample_no&gt;7&lt;/sample_no&gt;&lt;pat_no&gt;2000196036&lt;/pat_no&gt;&lt;pat_id&gt;2000196036&lt;/pat_id&gt;&lt;pat_name&gt;郑佳娜&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 10:27:38&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1993-10-13 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;28&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18620039661&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则;[西]急性阴道炎;[西]子宫纵隔?;[西]外阴白斑&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205267&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2843125193', 'blood_time': '2022-05-19 10:27:38', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.442
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.442, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 2.426
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 2.426, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2682.479
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 2682.479, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.138
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.138, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 7.169
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 7.169, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郑佳娜-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2943125194'
file_name = '郑佳娜-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:47:31 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1756', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2943125194&lt;/lis_Barcode&gt;&lt;sample_no&gt;8&lt;/sample_no&gt;&lt;pat_no&gt;2000196036&lt;/pat_no&gt;&lt;pat_id&gt;2000196036&lt;/pat_id&gt;&lt;pat_name&gt;郑佳娜&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 10:27:48&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1993-10-13 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;28&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18620039661&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则;[西]急性阴道炎;[西]子宫纵隔?;[西]外阴白斑&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205268&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2943125194', 'blood_time': '2022-05-19 10:27:48', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.541
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.541, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/郑佳娜-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2843125193'
file_name = '庄洁-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
# result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:46:48 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '2352', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2843125193&lt;/lis_Barcode&gt;&lt;sample_no&gt;7&lt;/sample_no&gt;&lt;pat_no&gt;2000196036&lt;/pat_no&gt;&lt;pat_id&gt;2000196036&lt;/pat_id&gt;&lt;pat_name&gt;郑佳娜&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 10:27:38&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1993-10-13 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;28&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18620039661&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则;[西]急性阴道炎;[西]子宫纵隔?;[西]外阴白斑&lt;/clinical_diag&gt;&lt;samp_name&gt;血清&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205267&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32025&lt;/lis_item_code&gt;&lt;lis_item_name&gt;雄激素5项(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32378&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32379&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;雄烯二酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32380&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;硫酸脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32381&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;脱氢表雄酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32383&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;双氢睾酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2843125193', 'blood_time': '2022-05-19 10:27:38', 'lis_combine_code': '32025', 'all_lis_item_code': ['32378', '32379', '32380', '32381', '32383'], 'all_lis_item_name': ['睾酮', '雄烯二酮', '硫酸脱氢表雄酮', '脱氢表雄酮', '双氢睾酮']}
# lis_item_nam--------
# 睾酮 32378 0.254
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'lis_combine_code': '32025', 'result': 0.254, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.882
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'lis_combine_code': '32025', 'result': 0.882, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1625.552
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'lis_combine_code': '32025', 'result': 1625.552, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.072
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'lis_combine_code': '32025', 'result': 0.072, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 2.222
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'lis_combine_code': '32025', 'result': 2.222, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/庄洁-激素检测报告-2022-05-25.pdf

# %%
hospSampleID = '2943125194'
file_name = '庄洁-激素检测报告-2022-05-25'
file_path = 'E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/' + file_name 
infile = file_path + '.xlsx'
# result_info , dct = get_excel_info(infile,hospSampleID,flag='5')
result_info , dct = get_excel_info(infile,hospSampleID,flag='17')
data1 = set_data1(dct)
# infile = file_path + '.pdf'
inpdf = file_path + '.pdf'
data2 = get_pdf(inpdf)
send_data(dct,data1,result_info,data2)
print(inpdf)
# Out:
# patient_info.header----
# {'Server': 'nginx/1.19.2', 'Date': 'Fri, 27 May 2022 01:46:42 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '1756', 'Connection': 'keep-alive'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><GetLisRequestResponse xmlns="http://tempuri.org/"><GetLisRequestResult>&lt;?xml version="1.0" encoding="utf-8"?&gt;&lt;Data&gt;&lt;Data_Row&gt;&lt;lis_Barcode&gt;2943125194&lt;/lis_Barcode&gt;&lt;sample_no&gt;8&lt;/sample_no&gt;&lt;pat_no&gt;2000196036&lt;/pat_no&gt;&lt;pat_id&gt;2000196036&lt;/pat_id&gt;&lt;pat_name&gt;郑佳娜&lt;/pat_name&gt;&lt;pat_bedNo&gt;&lt;/pat_bedNo&gt;&lt;spouse_info&gt;&lt;/spouse_info&gt;&lt;blood_time&gt;2022-05-19 10:27:48&lt;/blood_time&gt;&lt;pat_sex&gt;0&lt;/pat_sex&gt;&lt;pat_birthday&gt;1993-10-13 00:00:00&lt;/pat_birthday&gt;&lt;pat_age&gt;28&lt;/pat_age&gt;&lt;pat_ageunit&gt;0&lt;/pat_ageunit&gt;&lt;pat_tel&gt;18620039661&lt;/pat_tel&gt;&lt;dept_name&gt;妇科门诊(越秀)&lt;/dept_name&gt;&lt;doctor_name&gt;余凡&lt;/doctor_name&gt;&lt;doctor_tel&gt;&lt;/doctor_tel&gt;&lt;clinical_diag&gt;[西]月经不规则;[西]急性阴道炎;[西]子宫纵隔?;[西]外阴白斑&lt;/clinical_diag&gt;&lt;samp_name&gt;全血&lt;/samp_name&gt;&lt;pat_Remark&gt;&lt;/pat_Remark&gt;&lt;Pat_From&gt;门诊&lt;/Pat_From&gt;&lt;Pat_ID&gt;10494202205268&lt;/Pat_ID&gt;&lt;pat_CardNo&gt;&lt;/pat_CardNo&gt;&lt;LisItems&gt;&lt;lis_item_code&gt;32024&lt;/lis_item_code&gt;&lt;lis_item_name&gt;17α羟孕酮(爱湾)&lt;/lis_item_name&gt;&lt;SubItems&gt;&lt;lis_subitem_code&gt;32382&lt;/lis_subitem_code&gt;&lt;lis_subitem_name&gt;17α-羟孕酮&lt;/lis_subitem_name&gt;&lt;/SubItems&gt;&lt;/LisItems&gt;&lt;/Data_Row&gt;&lt;/Data&gt;</GetLisRequestResult></GetLisRequestResponse></soap:Body></soap:Envelope>
# HTMLParser parsering data
# ----patient_info-all_lis_item_name dct -----
# {'lis_Barcode': '2943125194', 'blood_time': '2022-05-19 10:27:48', 'lis_combine_code': '32024', 'all_lis_item_code': ['32382'], 'all_lis_item_name': ['17α-羟孕酮']}
# lis_item_nam--------
# 17α-羟孕酮 32382 0.403
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'lis_combine_code': '32024', 'result': 0.403, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/linuxPathFile/shenZhen_CentOs/project/long-term-proj/pcos/PCOS_transfer_data-new/数据/省妇幼报告/庄洁-激素检测报告-2022-05-25.pdf

# %%
excel_file_path = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31'
all_excel = list_all_files(excel_file_path)
all_excel 
# main_send_2type(excel_file_path)
# Out:
# ['E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31\\陈炜欣-激素检测报告-2022-05-31.xlsx']

# %%
for excel_file in all_excel:
    print(excel_file)
    main_send_2type(excel_file)
# Out:
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31\陈炜欣-激素检测报告-2022-05-31.xlsx
# lis_item_nam--------
# 睾酮 32378 0.393
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.393, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.443
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1.443, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2190.495
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 2190.495, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.085
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.085, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.745
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 3.745, 'ext_combine_code': '32025'}
# patient_info.text----
# <!DOCTYPE html>
# <html lang="zh-CN">
#
# <html>
# <head>
# 	<meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<title>æ¾ä¸å°</title>
# <style>
#     body {
#         width: 35em;
#         margin: 0 auto;
#         font-family: Tahoma, Verdana, Arial, sans-serif;
#     }
# 	#showIP{
# 		color: red;
# 	}
# </style>
# <script type="text/javascript" src="http://pv.sohu.com/cityjson?ie=utf-8" charset="utf-8">
# </script>
# <script>
# window.onload = function(){
# 	var ss = returnCitySN['cip'] + ' ' + returnCitySN['cname'];
# 	document.getElementById("showIP").innerHTML = 'æ¨çIPå°åä¸ºï¼' + ss;
# }
# </script>
# </head>
# <body>
# <h1>404æ¾ä¸å°</h1>
# <p>å¯¹ä¸èµ·ï¼æ¾ä¸å°ç½é¡µäºï¼è¯·è¿ç¹åæ¥ççå§ï¼å¥½åï¼</p>
# <div id="showIP"></div>
# </body>
# </html>
#
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31\陈炜欣-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.448
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.448, 'ext_combine_code': '32024'}
# patient_info.text----
# <!DOCTYPE html>
# <html lang="zh-CN">
#
# <html>
# <head>
# 	<meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<title>æ¾ä¸å°</title>
# <style>
#     body {
#         width: 35em;
#         margin: 0 auto;
#         font-family: Tahoma, Verdana, Arial, sans-serif;
#     }
# 	#showIP{
# 		color: red;
# 	}
# </style>
# <script type="text/javascript" src="http://pv.sohu.com/cityjson?ie=utf-8" charset="utf-8">
# </script>
# <script>
# window.onload = function(){
# 	var ss = returnCitySN['cip'] + ' ' + returnCitySN['cname'];
# 	document.getElementById("showIP").innerHTML = 'æ¨çIPå°åä¸ºï¼' + ss;
# }
# </script>
# </head>
# <body>
# <h1>404æ¾ä¸å°</h1>
# <p>å¯¹ä¸èµ·ï¼æ¾ä¸å°ç½é¡µäºï¼è¯·è¿ç¹åæ¥ççå§ï¼å¥½åï¼</p>
# <div id="showIP"></div>
# </body>
# </html>
#
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31\陈炜欣-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/陈炜欣-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file)
# Out:
# lis_item_nam--------
# 睾酮 32378 0.393
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.393, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.443
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1.443, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2190.495
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 2190.495, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.085
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.085, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.745
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 3.745, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/陈炜欣-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.448
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.448, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/陈炜欣-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file)
# Out:
# lis_item_nam--------
# 睾酮 32378 0.272
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.272, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.966
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.966, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 728.003
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 728.003, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.076
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.076, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 1.13
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1.13, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.568
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.568, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/梁金娟-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file) 
# TODO
# Out:
# lis_item_nam--------
# 睾酮 32378 0.431
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.431, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 2.383
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 2.383, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2562.361
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 2562.361, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.088
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.088, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 7.493
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 7.493, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/梁金娟-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.859
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.859, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/梁金娟-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/王华珍-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file) 
#TODO
# Out:
# lis_item_nam--------
# 睾酮 32378 0.32
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.32, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.782
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.782, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 1712.141
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1712.141, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.091
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.091, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 3.234
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 3.234, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/王华珍-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.152
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.152, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/王华珍-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file)
# Out:
# lis_item_nam--------
# 睾酮 32378 0.272
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.272, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 0.966
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.966, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 728.003
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 728.003, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.076
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.076, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 1.13
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1.13, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.568
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.568, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>success</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/谢莉莎-激素检测报告-2022-05-31.pdf

# %%
excel_file = 'E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/许慧敏-激素检测报告-2022-05-31.xlsx'
main_send_2type(excel_file) 
# TODO
# Out:
# lis_item_nam--------
# 睾酮 32378 0.461
# ********************
# {'ext_item_code': '32378', 'lis_item_name': '睾酮', 'lis_item_code': '32378', 'result_reference': '0.02-0.45', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.461, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 雄烯二酮 32379 1.746
# ********************
# {'ext_item_code': '32379', 'lis_item_name': '雄烯二酮', 'lis_item_code': '32379', 'result_reference': ' 0.30-2.35', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 1.746, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 硫酸脱氢表雄酮 32380 2443.106
# ********************
# {'ext_item_code': '32380', 'lis_item_name': '硫酸脱氢表雄酮', 'lis_item_code': '32380', 'result_reference': '280-3900', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 2443.106, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 双氢睾酮 32383 0.132
# ********************
# {'ext_item_code': '32383', 'lis_item_name': '双氢睾酮', 'lis_item_code': '32383', 'result_reference': '＜0.30', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 0.132, 'ext_combine_code': '32025'}
# lis_item_nam--------
# 脱氢表雄酮 32381 4.455
# ********************
# {'ext_item_code': '32381', 'lis_item_name': '脱氢表雄酮', 'lis_item_code': '32381', 'result_reference': '19-30岁<13\n31-40岁<10\n41-50岁<8', 'result_unit': 'ng/mL', 'lis_combine_code': '32025', 'result': 4.455, 'ext_combine_code': '32025'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/许慧敏-激素检测报告-2022-05-31.pdf
# lis_item_nam--------
# 17α-羟孕酮 32382 0.968
# ********************
# {'ext_item_code': '32382', 'lis_item_name': '17α-羟孕酮', 'lis_item_code': '32382', 'result_reference': '卵泡期0.09-2.00;黄体期0.3-2.34', 'result_unit': 'ng/mL', 'lis_combine_code': '32024', 'result': 0.968, 'ext_combine_code': '32024'}
# patient_info.text----
# <?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://www.w3.org/2003/05/soap-envelope" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><UploadLisRepDataResponse xmlns="http://tempuri.org/"><UploadLisRepDataResult>error:列名 'pat_reach_date' 无效。
# 列名 'pat_outreport_type' 无效。</UploadLisRepDataResult></UploadLisRepDataResponse></soap:Body></soap:Envelope>
# E:/project/common/2022/05/5.31/省妇幼pcos报告-2022-05-31/许慧敏-激素检测报告-2022-05-31.pdf
